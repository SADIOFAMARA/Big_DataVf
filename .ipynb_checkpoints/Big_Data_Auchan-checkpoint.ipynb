# %% [markdown]
# <h1 style="text-align:center;color:green;font-size:30px;font-family:ALGERIAN;border:solid">Projet de Big Data : Mise en place d'un système pour suivre les prix sur le site Auchan</h1>

# %% [markdown]
# ## Importation des  librairies

# %%
# pip install ydata-profiling
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import pandas as pd
import json
from dash import Dash, html, dash_table, dcc, callback, Output, Input
import pandas as pd
import plotly.express as px
import numpy as np
import dash_bootstrap_components as dbc
import matplotlib.pyplot as plt
import seaborn as sns
from ydata_profiling import ProfileReport

# %%
# Chemin du fichier JSON
file_path = r'C:\Users\lenovo\Desktop\ISE2_ENSAE_2024\Smestre 1\Big Data&ML\auchan.json'

# Importation du fichier JSON dans un DataFrame
df = pd.read_json(file_path)

# %% [markdown]
# <h1 style="text-align:left;color:blue;font-size:30px;font-family:TIMES NEW ROMAN">I.Analyse exploratoire</h1>

# %%
df.shape
# Out:
# (3821, 11)

# %% [markdown]
# Notre base contient 3821 observations de 11 variables

# %% [markdown]
# <h1 style="text-align:left;color:black;font-size:20px;font-family:times new roman"> Affichage des premières lignes de la base</h1>

# %%
df.head(20)
# Out:
#     category_id        category                     subcategory  \
# 0           104  Epicerie Salée                  Plats cuisinés
# 1           104  Epicerie Salée                  Plats cuisinés
# 2           104  Epicerie Salée                  Plats cuisinés
# 3           104  Epicerie Salée                  Plats cuisinés
# 4           104  Epicerie Salée                  Plats cuisinés
# 5           104  Epicerie Salée                  Plats cuisinés
# 6           104  Epicerie Salée                  Plats cuisinés
# 7           104  Epicerie Salée                  Plats cuisinés
# 8           104  Epicerie Salée                  Plats cuisinés
# 9           104  Epicerie Salée                  Plats cuisinés
# 10          104  Epicerie Salée                  Plats cuisinés
# 11          104  Epicerie Salée                  Plats cuisinés
# 12          104  Epicerie Salée                  Plats cuisinés
# 13          104  Epicerie Salée                  Plats cuisinés
# ...

# %%
df.describe()
# Out:
#        category_id  subcategory_id    product_id
# count  3821.000000     3821.000000  3.821000e+03
# mean    127.642502      179.543313  4.685766e+06
# std      29.052154       97.099186  2.099496e+07
# min      91.000000       93.000000  1.000000e+00
# 25%     104.000000      140.000000  1.778000e+03
# 50%     137.000000      162.000000  4.869000e+03
# 75%     151.000000      199.000000  7.905000e+03
# max     232.000000     1172.000000  9.882776e+07

# %%
df.isna().sum()
# Out:
# category_id        0
# category           0
# subcategory        0
# subcategory_id     0
# product_id         0
# title              0
# price              0
# old_price          0
# image_url          0
# is_out_of_stock    0
# scraping_date      0
# dtype: int64

# %% [markdown]
# Il n'existe pas de valeurs manquantes pour chaque variables de la base

# %%
# Ignorer les valeurs manquantes avant de convertir en entier
df['price'] = df['price'].str.replace('CFA', '', regex=False) \
                         .str.replace(r'\s+', '', regex=True)

df['old_price'] = df['old_price'].str.replace('CFA', '', regex=False) \
                                 .str.replace(r'\s+', '', regex=True)

# Convertir en entier en ignorant les valeurs non convertibles
df['price'] = pd.to_numeric(df['price'], errors='coerce').fillna(0).astype(int)
df['old_price'] = pd.to_numeric(df['old_price'], errors='coerce').fillna(0).astype(int)

# Vérifier le résultat
print(df[['price', 'old_price']].head())
# Out:
#    price  old_price
# 0   3290          0
# 1   1525          0
# 2   2650          0
# 3   2050          0
# 4   2050          0

# %%
# Conversion des bases au format excel et csv
df.to_csv('produits.csv', index=False, encoding='utf-8')

#df.to_csv('produits.csv', index=False, encoding='utf-8')

# %% [markdown]
# ## Data Visualization

# %%
## Visualisation de la distributin des variables 

## visualization des catégories des variables de type object 

for col in df.select_dtypes('object'):
    print(f'{col :-<30} {df[col].unique()}')
# Out:
# category---------------------- ['Epicerie Salée' 'Petfood & Animalerie' 'Epicerie Sucrée'
#  'Maison & Loisirs' 'Entretien de la maison' 'Bébé & Puériculture'
#  'Fruits & Légumes' 'Hygiène & Beauté & parapharmacie' 'Bio'
#  'Produits Surgelés' 'Produits Frais' 'Boissons'
#  'Boulangerie & Patisserie']
# subcategory------------------- ['Plats cuisinés' 'Sauces & Tomates & Mayonnaises' 'Conserves de viande'
#  'Conserves de légumes' 'Céréales & Riz & Couscous & Semoules'
#  'Soupes liquides & déshydratées & instantanées' 'Huiles cuisine'
#  'Chips & Tuiles & Apéritifs' 'Vinaigres & Vinaigrettes'
#  'Sel & Poivre & Epices & Herbes' 'Bouillon & Aides à la cuisine'
#  'Autres animaux' 'Pâtes alimentaires & Purée'
#  'Gaufrettes & Gâteaux moelleux' 'Produits du monde'
#  'Accessoires & Soins animaliers' 'Jeux & Jouets' 'Chats' 'Chiens'
#  'Papeterie & Fourniture & Bureau' 'Condiments & Olives & Cornichons'
#  'Conserves de poisson' 'Bricolage & Jardin & Outillage'
# ...

# %%
## visualization des variables de type integer

for col in df.select_dtypes('int'):
    plt.figure(figsize=(10,5))
    sns.distplot(df[col])
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_24232\960487242.py:5: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_24232\960487242.py:5: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# ...

# %% [markdown]
# ## Suivi des produits les plus chers

# %%
# Calculer le prix moyen par catégorie
category_avg_price = df.groupby('category')['price'].mean()

# Tracer le camembert
plt.figure(figsize=(10, 7))
plt.pie(category_avg_price, labels=category_avg_price.index, autopct='%1.1f%%', startangle=140)

# Titre du graphique
plt.title("Répartition des produits les plus chers par catégorie (prix moyen)")
plt.show()

# %% [markdown]
# On constate que les produits les plus chers sont représentés par le diagramme circulaire ci-dessus. Nous remarquons que les produits comme Maisons& Loisirs sont les plus chers de tous les autres, viennent ensuite les Boissons, les Petfood & Animaleries, les produits surgelés et Bébé & puériculture.
# Les autres produits sont les produits les moins chers.

# %% [markdown]
# <h1 style="text-align:center;color:blue;font-size:30px;font-family:TIMES NEWS"> Evolution du prix des produits (category) en fonction du temps</h1>

# %%
# Convertir 'scraping_date' en format datetime
df['scraping_date'] = pd.to_datetime(df['scraping_date'])

# Tracer l'évolution des prix au fil du temps
plt.figure(figsize=(10, 6))
plt.plot(df['scraping_date'], df['price'], marker='o')
plt.title('Évolution des prix en fonction du temps')
plt.xlabel('Date de scraping')
plt.ylabel('Prix')
plt.grid(True)
plt.show()

# %%
# Ajustez la taille de la figure
plt.figure(figsize=(12, 6))

# Créez un histogramme des prix, groupé par catégorie, avec une courbe de densité
sns.histplot(data=df, x="price", hue="category", kde=True, multiple="stack")

# Ajoutez des labels et un titre pour plus de clarté
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.title("Histogramme des prix par catégorie avec courbe de densité")

# Affichez le graphique
plt.show()

# %%
profile=ProfileReport(df,title= "ANALYSE DESCRIPTIVE")
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.6.4&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-10-27 12:54:51.590561&quot;&gt;&lt;title&gt;ANALYSE DESCRIPTIVE&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
# Initialisation de l'application et choix du theme
external_stylesheets = [dbc.themes.LUMEN] # dbc.themes.BOOTSTRAP, dbc.themes.CERULEAN
app = Dash(__name__, external_stylesheets=external_stylesheets)

# %%
# the style arguments for the sidebar. We use position:fixed and a fixed width
SIDEBAR_STYLE = {
    "position": "fixed",
    "top": 0,
    "left": 0,
    "bottom": 0,
    "width": "16rem",
    "padding": "2rem 1rem",
    "background-color": "#f8f9fa",
}
# the styles for the main content position it to the right of the sidebar and
# add some padding.
CONTENT_STYLE = {
    "margin-left": "18rem",
    "margin-right": "2rem",
    "padding": "2rem 1rem",
}
sidebar = html.Div(
    [
        html.H2("Menu", className="display-4"),
        html.Hr(),
        html.P(
            "Cette applicaton a ete concu pour suivre le prix des produits de Auchan.", className="lead"
        ),
        dbc.Nav(
            [
                dbc.NavLink("Acceuil", href="/", active="exact"),
                dbc.NavLink("Visualisation", href="/visualisation", active="exact"),
            ],
            vertical=True,
            pills=True,
        ),
    ],
    style=SIDEBAR_STYLE,
)
# App layout
app.layout = dbc.Container([
    dbc.Row([
        html.Div('DASHBORD DE SUIVI DES PRIX DE AUCHAN', className="text-primary text-center fs-1", style={'textAlign': 'right', 'padding-left': '270px', 'font-weight': 'bold'})
    ]),

    dbc.Row([
        dbc.Card([
            html.Div([
    dcc.Location(id='url', refresh=False),
    sidebar,
    html.Div(id='page-content', style=CONTENT_STYLE)
])
        ])
    ]),
], fluid=True)

# %%
@callback(Output("page-content", "children"), Input("url", "pathname"))
def render_page_content(pathname):
    if pathname == "/":
        return home_layout
    elif pathname == "/visualisation":
        return dashbord_layout

    # If the user tries to reach a different page, return a 404 message
    return html.Div(
        [
            html.H1("404: Not found", className="text-danger"),
            html.Hr(),
            html.P(f"The pathname {pathname} was not recognised..."),
        ],
        className="p-3 bg-light rounded-3",
    )

# %%
home_layout = dbc.Container([
    dbc.Col([
        html.Div([
    html.H1("Bienvenue sur la page d'accueil du dashbord", style={'textAlign': 'center', 'font-weight': 'bold'}),
    ])
    ]),
    dbc.CardImg(src="/assets/Photo1.jpeg", top=True),
    html.H2('DESCRIPTION DE L`APPLICATION'),
    html.H2("L'objectif de cette application est de faire le suivi des prix de Auchan."),
])



# Layout de l'application
dashbord_layout = html.Div([
    html.H1("Catalogue de Produits", style={'textAlign': 'center', 'font-weight': 'bold'}),

    # Dropdown pour sélectionner la catégorie
    html.Label("Sélectionnez une catégorie", style={'textAlign': 'center', 'font-weight': 'bold'}),
    dcc.Dropdown(
        id='category-dropdown',
        options=[{'label': cat, 'value': cat} for cat in df['category'].unique()],
        value=df['category'].unique()[0]
    ),
    
    # Section pour afficher les produits
    dbc.Row(id='product-list')
])

# Callback pour mettre à jour la liste des produits en fonction de la catégorie sélectionnée
@callback(
    Output('product-list', 'children'),
    Input('category-dropdown', 'value')
)
def update_products(selected_category):
    # Filtrer les produits par catégorie
    filtered_df = df[df['category'] == selected_category]

    # Créer des cartes de produit
    products = []
    for _, row in filtered_df.iterrows():
        product_card = dbc.Col([
            html.Div([
            html.Img(src=row['image_url'], style={'width': '100px', 'height': '100px'}),
            html.H4(row['title']),
            html.P(f"Prix : {row['price']}", style={'font-weight': 'bold'}),
            html.P("Disponible" if not row['is_out_of_stock'] else "Rupture de stock")
            ], style={'border': '1px solid #ccc', 'padding': '10px', 'margin': '10px'})
            ], width=3)  
        products.append(product_card)
    
    return products

# Lancer l'application
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# ---------------------------------------------------------------------------
# NotFound                                  Traceback (most recent call last)
# NotFound: 404 Not Found: The requested URL was not found on the server. If you entered the URL manually please check your spelling and try again.
